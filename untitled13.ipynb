# %% [markdown]
# <a href="https://colab.research.google.com/github/Jridi1/hello-world/blob/main/untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# the scipy version packaged with colab is not tolerant of misformated WAV files.
# install the latest version.
# !pip3 install -U scipy
# !pip install pydub
# !git clone https://github.com/jnordberg/tortoise-tts.git
# %cd tortoise-tts
# !pip3 install transformers==4.19.0
# !pip3 install -r requirements.txt
# !python3 setup.py install

# %%
# Imports used through the rest of the notebook.
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F

import IPython

from tortoise.api import TextToSpeech
from tortoise.utils.audio import load_audio, load_voice, load_voices

# This will download all the models used by Tortoise from the HuggingFace hub.
tts = TextToSpeech()

# %%
from pydub import AudioSegment
def text_to_speech(text = "This is a text  to voice DEMO provided by factory of the sol", preset= "fast", voice = 'geralt', output = '/content/tortoise-tts/tortoise/voices/file3.mp3'):
  # Load it and send it through Tortoise.
  voice_samples, conditioning_latents = load_voice(voice)
  gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                            preset=preset)
  torchaudio.save('generated.wav', gen.squeeze(0).cpu(), 24000)
  generated_voice = IPython.display.Audio('generated.wav')
  AudioSegment.from_wav("generated.wav").export(output, format="mp3")
  return(generated_voice)

# %%
#daniel, deniro
text_to_speech(voice = 'weaver', text = 'This is a text  to voice DEMO provided by factory of the sol!    ', output = '/content/tortoise-tts/tortoise/voices/file.mp3')
# Out:
# Generating autoregressive samples..
# 100%|██████████| 6/6 [00:19<00:00,  3.31s/it]
# Computing best candidates using CLVP and CVVP
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# 100%|██████████| 6/6 [00:09<00:00,  1.54s/it]
# Transforming autoregressive outputs into audio..
# 100%|██████████| 80/80 [00:09<00:00,  8.77it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
